# %%
import pandas as pd

# %%
batting_df_norm_final = pd.read_csv('data/batting_norm.csv', index_col=0)
batting_df_norm_final[batting_df_norm_final['year'] == 1955].sort_values(by='hr')
# Out:
#              ab        bb    double         g         h       hbp        hr  \
# 37774 -0.716508 -0.622894 -0.626327 -0.870177 -0.662207 -0.452194 -0.465555
# 37833 -0.705100 -0.622894 -0.626327 -0.934600 -0.662207 -0.452194 -0.465555
# 37832 -0.573912 -0.577782 -0.500137 -0.633962 -0.642136 -0.452194 -0.465555
# 37831 -0.613839 -0.442445 -0.626327  0.053210 -0.622064 -0.452194 -0.465555
# 37829 -0.722212 -0.622894 -0.626327 -0.999022 -0.662207 -0.452194 -0.465555
# ...         ...       ...       ...       ...       ...       ...       ...
# 37814  2.118305  4.294344  2.276046  2.007355  2.228092  0.133156  5.156064
# 37996  2.340756  4.068783  3.664138  2.157674  2.669666  0.133156  5.293176
# 37473  2.671579  1.407159  3.033187  2.286519  2.870381  0.718506  5.567402
# 37750  2.762841  2.354517  2.528427  2.265045  3.191525  1.889206  5.978740
# 37817  2.580317  2.940976  1.645096  2.243570  3.051025  1.889206  6.527190
#
# ...

# %%
# verify that the normalization makes sense - check for good players
batting_df_norm_final.groupby('player_id').sum().drop(columns='year')['hr'].sort_values()[-20:]
# Out:
# player_id
# musiast01     64.223510
# thomeji01     64.889796
# mcgwima01     64.921242
# sosasa01      65.726377
# mantlmi01     67.205821
# pujolal01     68.439584
# griffke02     68.891685
# schmimi01     70.681344
# killeha01     70.978293
# jacksre01     71.821274
# robinfr02     72.568452
# willite01     76.909964
# rodrial01     77.095111
# gehrilo01     81.381527
# mayswi01      82.059074
# foxxji01      83.412168
# ottme01       84.862388
# bondsba01     86.153874
# aaronha01     97.603013
# ruthba01     157.331629
# Name: hr, dtype: float64
