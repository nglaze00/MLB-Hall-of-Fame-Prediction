# %% [markdown]
# # Code to make Hall of Fame predictions for specific players

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Normalize 2010 - 2020 data (from Baseball Savant)

# %%
def preprocess_bs_table(filename):
    # select columns, drop 2020 (short season)
    batting_df = pd.read_csv(filename)
    batting_df['player_id'] = (batting_df[' first_name'] + batting_df['last_name']).str[1:]
    batting_df = batting_df[['player_id', 'b_ab', 'b_walk', 'b_double', 'b_game', 'b_total_hits', 'b_hit_by_pitch', 'b_home_run', 'r_run', 'b_rbi', 'r_total_stolen_base', 'b_total_sacrifices', 'b_strikeout', 'b_triple', 'year']]
    batting_df = batting_df[batting_df['year'] != 2020]
    
    # normalize
    yearly_means = batting_df.groupby('year').mean()
    yearly_stds = batting_df.groupby('year').std()
    batting_df_norm_year = batting_df.apply(lambda row: (row - yearly_means.loc[row['year']]) / yearly_stds.loc[row['year']], axis=1)
    batting_df_norm_year['year'] = batting_df['year']
    batting_df_norm_year['player_id'] = batting_df['player_id']
    
    # save
    batting_df_norm_year.to_csv('../data_normalized/batting_norm_2010_2020.csv')

# %%
preprocess_bs_table('../data/batting_2010_2020.csv')

# %% [markdown]
# # Build samples for specific player IDs

# %%
new_df_norm = pd.read_csv('../data_normalized/batting_norm_2010_2020.csv').drop(columns='Unnamed: 0')
old_df_norm = pd.read_csv('../data_normalized/batting_norm_batters_only.csv').drop(columns='Unnamed: 0')
def player_df(player_id, dataset='new'):
    """
    Returns DataFrame representing a player's stats
    
    dataset="new" if player played after 2009
    dataset="old" if player played before 2010
    """
    if dataset == 'new':
        p_df = new_df_norm[new_df_norm['player_id'] == player_id].sort_values('year').drop(columns=['player_id'])
    else:
        p_df = old_df_norm[old_df_norm['player_id'] == player_id].sort_values('year').drop(columns=['player_id'])
    p_df['years_played'] = np.arange(1, p_df.shape[0]+1)
    return p_df

# %%
def build_samples(player_ids, fmt='ts', dataset='new'):
    """
    Builds aggregate or time series test set, given a list of player ids, the format (ts or agg) and the dataset to use (new or old)
    """
    if fmt == 'ts':
        X_test = np.zeros((len(player_ids), 25, 13))
    else:
        X_test = np.zeros((len(player_ids), 14))
        
    for i, pid in enumerate(player_ids):
        p_df = player_df(pid, dataset=dataset)
        if fmt == 'ts':
            X_test[i, :p_df['years_played'].max()] = p_df.drop(columns=['years_played', 'year']).to_numpy()
        else:
            p_df_agg = p_df.drop(columns=['year', 'years_played']).sum(axis=0)
            X_test[i] = np.concatenate((p_df_agg.to_numpy(), [p_df['years_played'].max()]))
    
    return X_test

# %% [markdown]
# # make predictions using LSTM

# %%
def predict(model, player_ids, fmt='ts', dataset='new'):
    """
    Makes a prediction using a loaded model (must have .predict() function)
    """
    X_test = build_samples(player_ids, fmt=fmt, dataset=dataset)
    preds = model.predict(X_test)
    return list(sorted(zip(player_ids, 100 * model.predict(X_test)[:, 1]), key=lambda x:-x[1]))

# %%
from keras.models import load_model

# %%
lstm = load_model('good_lstm/')

# %%
started_after_2011 = (batting_df_norm_year.groupby('player_id').agg('min')['year'] >= 2011)
ids_after_2011 = started_after_2011.index[started_after_2011]

# %%
predict(lstm, [''], dataset='new')

# %%
# All players before 2010
predict(lstm, old_df_norm['player_id'].unique(), dataset='old')
# Out:
# [('yastrca01', 99.99292),
#  ('morgajo02', 99.9925),
#  ('kalinal01', 99.989914),
#  ('sheffga01', 99.98927),
#  ('aaronha01', 99.98672),
#  ('bondsba01', 99.98339),
#  ('musiast01', 99.98079),
#  ('griffke02', 99.97782),
#  ('robinbr01', 99.977104),
#  ('hunteto01', 99.97638),
#  ('ripkeca01', 99.96563),
#  ('henderi01', 99.96538),
#  ('thomeji01', 99.95883),
#  ('jonesch06', 99.95764),
#  ('fiskca01', 99.955734),
#  ('rosepe01', 99.95361),
#  ('brettge01', 99.95192),
#  ('murraed02', 99.9507),
#  ('palmera01', 99.95017),
#  ('rodrial01', 99.94198),
#  ('mayswi01', 99.936455),
#  ('ortizda01', 99.93531),
#  ('winfida01', 99.92783),
#  ('mcgrifr01', 99.927444),
#  ('jacksre01', 99.92624),
#  ('mccovwi01', 99.901794),
#  ('jeterde01', 99.90079),
#  ('raineti01', 99.89952),
#  ('evansdw01', 99.89479),
#  ('thomafr04', 99.89083),
#  ('gehrich01', 99.88813),
#  ('ottme01', 99.883934),
#  ('gonzalu01', 99.87595),
#  ('biggicr01', 99.860504),
#  ('stargwi01', 99.8558),
#  ('ramirma02', 99.84808),
#  ('willibi01', 99.84285),
#  ('parkeda01', 99.81088),
#  ('willite01', 99.810394),
#  ('whitalo01', 99.78146),
#  ('molitpa01', 99.77744),
#  ('ruthba01', 99.768364),
#  ('cuyleki01', 99.763),
#  ('simmote01', 99.754265),
#  ('vernomi01', 99.75423),
#  ('dawsoan01', 99.74408),
#  ('bankser01', 99.7352),
#  ('simmoal01', 99.72399),
#  ('oliveal01', 99.72101),
#  ('gehrilo01', 99.71962),
#  ('beltrad01', 99.71339),
#  ('baineha01', 99.703064),
#  ('mcraeha01', 99.69794),
#  ('beltrca01', 99.6967),
#  ('brocklo01', 99.69285),
#  ('fairlro01', 99.692635),
#  ('staubru01', 99.68792),
#  ('foxne01', 99.68575),
#  ('foxxji01', 99.67229),
#  ('heltoto01', 99.666145),
#  ('abreubo01', 99.65771),
#  ('aloumo01', 99.65534),
#  ('yountro01', 99.65124),
#  ('perezto01', 99.6432),
#  ('cronijo01', 99.63726),
#  ('guerrvl01', 99.6168),
#  ('rolensc01', 99.601776),
#  ('whitede03', 99.58814),
#  ('robinfr02', 99.5858),
#  ('burksel01', 99.57106),
#  ('sosasa01', 99.56115),
#  ('murphda05', 99.55462),
#  ('pujolal01', 99.52739),
#  ('berrayo01', 99.5125),
#  ('schmimi01', 99.50887),
#  ('mantlmi01', 99.50529),
#  ('cartega01', 99.49629),
#  ('polanpl01', 99.49515),
#  ('walkela01', 99.48201),
#  ('hornsro01', 99.48159),
#  ('gosligo01', 99.43883),
#  ('cartejo01', 99.432724),
#  ('sandere02', 99.43029),
#  ('riceji01', 99.42439),
#  ('cepedor01', 99.41649),
#  ('trammal01', 99.40794),
#  ('heilmha01', 99.397995),
#  ('seweljo01', 99.367805),
#  ('bagweje01', 99.36433),
#  ('mizejo01', 99.358215),
#  ('matheed01', 99.34403),
#  ('clarkwi02', 99.328964),
#  ('reesepe01', 99.32337),
#  ('teixema01', 99.300064),
#  ('martied01', 99.28433),
#  ('adcocjo01', 99.28184),
#  ('camermi01', 99.28093),
#  ('hartnga01', 99.26571),
#  ('cramedo01', 99.23549),
#  ('bellbu01', 99.22539),
#  ('cabremi01', 99.221146),
#  ('santoro01', 99.214516),
#  ('furilca01', 99.18663),
#  ('olivato01', 99.17386),
#  ('rodriiv01', 99.16533),
#  ('medwijo01', 99.144325),
#  ('leeca01', 99.10422),
#  ('hollima01', 99.09312),
#  ('utleych01', 99.02637),
#  ('greenha01', 99.02435),
#  ('willike01', 99.02208),
#  ('belleal01', 99.00511),
#  ('applilu01', 98.99454),
#  ('lombaer01', 98.986),
#  ('surhobj01', 98.96847),
#  ('dickebi01', 98.95303),
#  ('gwynnto01', 98.949135),
#  ('bottoji01', 98.93987),
#  ('dimagjo01', 98.90803),
#  ('walkedi02', 98.88715),
#  ('leede02', 98.84121),
#  ('canoro01', 98.81572),
#  ('puckeki01', 98.76916),
#  ('berkmla01', 98.76796),
#  ('kellge01', 98.76309),
#  ('boudrlo01', 98.760605),
#  ('benchjo01', 98.757744),
#  ('cochrmi01', 98.6823),
#  ('judgejo01', 98.64833),
#  ('bellge02', 98.647934),
#  ('hodgegi01', 98.64054),
#  ('kleinch01', 98.61951),
#  ('nichobi01', 98.5926),
#  ('kinerra01', 98.576126),
#  ('gracema01', 98.57546),
#  ('ennisde01', 98.53082),
#  ('phillto02', 98.519554),
#  ('jonesan01', 98.502144),
#  ('larkiba01', 98.45801),
#  ('doerrbo01', 98.44122),
#  ('garcino01', 98.43406),
#  ('callijo01', 98.40751),
#  ('millebi02', 98.37109),
#  ('ordonma01', 98.35506),
#  ('thomsbo01', 98.34647),
#  ('gordosi01', 98.34557),
#  ('singlke01', 98.324066),
#  ('smithre06', 98.31965),
#  ('johnsbo01', 98.31111),
#  ('yorkru01', 98.30825),
#  ('elliobo01', 98.286095),
#  ('scottge02', 98.28477),
#  ('roushed01', 98.28201),
#  ('olerujo01', 98.28122),
#  ('troskha01', 98.23989),
#  ('wanerpa01', 98.20639),
#  ('hafeych01', 98.1701),
#  ('younger01', 98.16474),
#  ('bonilbo01', 98.16095),
#  ('gordojo01', 98.137634),
#  ('coopece01', 98.11777),
#  ('chambch01', 98.028305),
#  ('henrito01', 97.99427),
#  ('ramirar01', 97.96272),
#  ('jonesad01', 97.953514),
#  ('greensh01', 97.95103),
#  ('pippwa01', 97.93607),
#  ('manushe01', 97.91686),
#  ('snidedu01', 97.90073),
#  ('slaugen01', 97.87522),
#  ('smithoz01', 97.83956),
#  ('alomaro01', 97.81292),
#  ('jacobba01', 97.81038),
#  ('camparo01', 97.80077),
#  ('averiea01', 97.776184),
#  ('robinja02', 97.75839),
#  ('willibe02', 97.743675),
#  ('tulowtr01', 97.68569),
#  ('darkal01', 97.67256),
#  ('durhara01', 97.64406),
#  ('clemero01', 97.63128),
#  ('sierrru01', 97.62743),
#  ('bergewa01', 97.59817),
#  ('gonzaad01', 97.59675),
#  ('harpege02', 97.58824),
#  ('wilsoha01', 97.58147),
#  ('mazerbi01', 97.54039),
#  ('damonjo01', 97.53396),
#  ('larocad01', 97.53161),
#  ('howarel01', 97.52283),
#  ('terrybi01', 97.50032),
#  ('rizzuph01', 97.49052),
#  ('bellgu01', 97.475296),
#  ('boggswa01', 97.44856),
#  ('ausmubr01', 97.442345),
#  ('aparilu01', 97.41318),
#  ('groatdi01', 97.39589),
#  ('braunry02', 97.34919),
#  ('spencst01', 97.344086),
#  ('vidrojo01', 97.34331),
#  ('dejesda01', 97.33586),
#  ('hebneri01', 97.28929),
#  ('bondsbo01', 97.246895),
#  ('crandde01', 97.23428),
#  ('longoev01', 97.22273),
#  ('burnsge02', 97.19767),
#  ('kendaja01', 97.19295),
#  ('brunato01', 97.14352),
#  ('ethiean01', 97.07636),
#  ('bonurze01', 97.0472),
#  ('knoblch01', 97.030174),
#  ('dobyla01', 97.02903),
#  ('huffau01', 97.01199),
#  ('schoere01', 96.88197),
#  ('hamiljo03', 96.88065),
#  ('holmeto01', 96.87998),
#  ('marisro01', 96.862686),
#  ('grandcu01', 96.84305),
#  ('muellbi02', 96.83376),
#  ('powervi01', 96.82496),
#  ('mcquige02', 96.81653),
#  ('otisam01', 96.81437),
#  ('camildo01', 96.79905),
#  ('mondari01', 96.79128),
#  ('randowi01', 96.73775),
#  ('nettlgr01', 96.732925),
#  ('fernato01', 96.7157),
#  ('meuseir01', 96.7045),
#  ('colliri02', 96.67859),
#  ('ugglada01', 96.67044),
#  ('parrila02', 96.66662),
#  ('mosebll01', 96.645615),
#  ('campabe01', 96.628174),
#  ('carewro01', 96.61536),
#  ('tejadmi01', 96.61491),
#  ('floodcu01', 96.601364),
#  ('rolliji01', 96.579704),
#  ('kuheljo01', 96.56313),
#  ('downibr01', 96.55108),
#  ('bollifr01', 96.533424),
#  ('sislege01', 96.527725),
#  ('phillbr01', 96.52192),
#  ('skowrbi01', 96.51595),
#  ('rudijo01', 96.47835),
#  ('gibsoki01', 96.44314),
#  ('frymatr01', 96.412025),
#  ('wanerll01', 96.399574),
#  ('keltnke01', 96.30949),
#  ('mcdougi01', 96.27172),
#  ('felscha01', 96.25748),
#  ('pepitjo01', 96.243),
#  ('chapmsa01', 96.22178),
#  ('cashno01', 96.217804),
#  ('uptonju01', 96.186134),
#  ('falkbi01', 96.15804),
#  ('sanguma01', 96.15385),
#  ('ferreri01', 96.08389),
#  ('stantmi03', 96.00226),
#  ('hurstdo01', 95.94313),
#  ('lopezhe01', 95.9085),
#  ('traynpi01', 95.88049),
#  ('parkewe01', 95.86546),
#  ('butlebi03', 95.85932),
#  ('ortajo01', 95.843796),
#  ('ricesa01', 95.8375),
#  ('bartedi01', 95.82725),
#  ('bruceja01', 95.81705),
#  ('kentje01', 95.79114),
#  ('colavro01', 95.7786),
#  ('boyerke01', 95.77411),
#  ('murphdw01', 95.73616),
#  ('harrijo03', 95.70627),
#  ('tobinja01', 95.66745),
#  ('pinsova01', 95.66489),
#  ('kinslia01', 95.64667),
#  ('mccutan01', 95.63669),
#  ('ashburi01', 95.62882),
#  ('mccanbr01', 95.62096),
#  ('burrepa01', 95.588264),
#  ('westsa01', 95.584785),
#  ('lansfca01', 95.54312),
#  ('goodmiv01', 95.47815),
#  ('sandbry01', 95.47789),
#  ('youngro01', 95.47292),
#  ('cespeyo01', 95.36592),
#  ('greerru01', 95.36262),
#  ('hermabi01', 95.33314),
#  ('mattido01', 95.30955),
#  ('kellech01', 95.256584),
#  ('salmoti01', 95.2146),
#  ('fredejo01', 95.194176),
#  ('foxpe01', 95.190445),
#  ('bellda01', 95.16104),
#  ('konerpa01', 95.110115),
#  ('wrighta01', 95.097466),
#  ('dunnad01', 95.09372),
#  ('cruzjo01', 95.09063),
#  ('stonejo01', 95.08144),
#  ('drewjd01', 95.079216),
#  ('bochtbr01', 95.00413),
#  ('troutmi01', 94.973114),
#  ('victosh01', 94.85295),
#  ('peskyjo01', 94.82911),
#  ('gilliji01', 94.79979),
#  ('harpebr03', 94.78737),
#  ('cullero01', 94.78258),
#  ('sandopa01', 94.77907),
#  ('edmonji01', 94.74518),
#  ('mcraebr01', 94.73045),
#  ('dimagdo01', 94.730225),
#  ('gonzaca01', 94.728966),
#  ('frazito01', 94.71983),
#  ('coopewa01', 94.71309),
#  ('speiech01', 94.70121),
#  ('loneyja01', 94.610306),
#  ('donaljo02', 94.60764),
#  ('hudsoor01', 94.57576),
#  ('suzukic01', 94.57002),
#  ('wertzvi01', 94.56579),
#  ('rasmuco01', 94.562874),
#  ('markani01', 94.520294),
#  ('drewst01', 94.510605),
#  ('pencehu01', 94.45242),
#  ('brutobi01', 94.38256),
#  ('hausejo01', 94.35879),
#  ('rothbr01', 94.293945),
#  ('alfoned01', 94.27315),
#  ('seageky01', 94.27189),
#  ('mccosba01', 94.251205),
#  ('gilesma01', 94.22138),
#  ('killeha01', 94.20543),
#  ('lewisbu01', 94.20026),
#  ('lindsfr01', 94.188705),
#  ('aokino01', 94.181625),
#  ('kendrho01', 94.14429),
#  ('grudzma01', 94.12913),
#  ('hendrge01', 94.11788),
#  ('moonwa01', 94.11312),
#  ('northji01', 94.08945),
#  ('doziebr01', 94.08459),
#  ('bassljo01', 94.032646),
#  ('reynoma01', 94.010475),
#  ('combsea01', 94.00359),
#  ('virdobi01', 93.982864),
#  ('puigya01', 93.95584),
#  ('highan01', 93.9426),
#  ('cabreas01', 93.94056),
#  ('wilkebr01', 93.90838),
#  ('johnske05', 93.85194),
#  ('tuckemi01', 93.82562),
#  ('piazzmi01', 93.7563),
#  ('greenmi01', 93.7431),
#  ('carpema01', 93.64861),
#  ('bostoly01', 93.63648),
#  ('marshwi01', 93.59827),
#  ('minosmi01', 93.5956),
#  ('heywaja01', 93.591736),
#  ('valenjo02', 93.57767),
#  ('munsoth01', 93.5038),
#  ('jacksau01', 93.47851),
#  ('bandosa01', 93.47671),
#  ('tayloto02', 93.44926),
#  ('hendeda01', 93.4106),
#  ('wynnji01', 93.40024),
#  ('bancrda01', 93.3594),
#  ('willsbu01', 93.338776),
#  ('arenano01', 93.25964),
#  ('deshide01', 93.23351),
#  ('molinya01', 93.139114),
#  ('lucrojo01', 93.12221),
#  ('harpeto01', 93.09647),
#  ('krukjo01', 93.08514),
#  ('encarju01', 93.06647),
#  ('hassebu01', 93.01723),
#  ('castrst01', 92.97901),
#  ('kessido01', 92.947205),
#  ('hosmeer01', 92.922745),
#  ('goldspa01', 92.8301),
#  ('cruzjo02', 92.71353),
#  ('whitnpi01', 92.68918),
#  ('machama01', 92.66747),
#  ('portedi01', 92.660194),
#  ('raderdo02', 92.65385),
#  ('lopesda01', 92.520996),
#  ('parrage01', 92.48129),
#  ('cardele01', 92.44978),
#  ('spande01', 92.39006),
#  ('martest01', 92.38245),
#  ('vosmijo01', 92.315445),
#  ('mannle01', 92.28773),
#  ('cashda01', 92.24877),
#  ('odoulle01', 92.21947),
#  ('kirklwi01', 92.18618),
#  ('mccorfr01', 92.109726),
#  ('zobribe01', 92.09978),
#  ('lynnfr01', 92.09544),
#  ('blasido01', 91.9715),
#  ('grichbo01', 91.78731),
#  ('finlest01', 91.75897),
#  ('todtph01', 91.652),
#  ('siebeno01', 91.52528),
#  ('nealch01', 91.4703),
#  ('murphda08', 91.401405),
#  ('teahema01', 91.34277),
#  ('smithel02', 91.33285),
#  ('riosal01', 91.32275),
#  ('ruckejo01', 91.19169),
#  ('conigto01', 91.10643),
#  ('connojo04', 91.08378),
#  ('vanslan01', 90.95337),
#  ('werthja01', 90.95268),
#  ('reedjo01', 90.90713),
#  ('skinnbo01', 90.86796),
#  ('snydeco02', 90.82095),
#  ('hardyjj01', 90.793785),
#  ('thomale03', 90.749535),
#  ('charled01', 90.73334),
#  ('huntro01', 90.73073),
#  ('ramiral03', 90.67784),
#  ('ettenni01', 90.65553),
#  ('morame01', 90.60375),
#  ('priddje01', 90.53973),
#  ('willsma01', 90.48418),
#  ('bellbe01', 90.473274),
#  ('daviswi02', 90.30605),
#  ('randajo01', 90.28793),
#  ('renteed01', 90.24213),
#  ('gordoal01', 90.13676),
#  ('cabreme01', 90.12769),
#  ('cruzde01', 90.076675),
#  ('maypi01', 90.03807),
#  ('vaughar01', 90.02267),
#  ('beckegl01', 90.00656),
#  ('suhrgu01', 89.83769),
#  ('loftoke01', 89.80284),
#  ('puhlte01', 89.74082),
#  ('stephve01', 89.723465),
#  ('travice01', 89.58495),
#  ('jonesja04', 89.58425),
#  ('ackledu01', 89.49988),
#  ('roccomi01', 89.46355),
#  ('venabwi01', 89.43622),
#  ('bissode01', 89.34297),
#  ('irvinmo01', 89.27736),
#  ('petrori01', 89.2525),
#  ('higgipi01', 89.12178),
#  ('laryly01', 89.01607),
#  ('kipnija01', 88.90963),
#  ('cowenal01', 88.88477),
#  ('dickeco01', 88.88337),
#  ('manniri01', 88.85177),
#  ('bautijo02', 88.835106),
#  ('hackst01', 88.79789),
#  ('millafe01', 88.76361),
#  ('daviskh01', 88.723495),
#  ('walkene01', 88.6545),
#  ('peralda01', 88.53862),
#  ('gattiev01', 88.53694),
#  ('leachfr01', 88.521706),
#  ('youngmi02', 88.50545),
#  ('erstada01', 88.46112),
#  ('runnepe01', 88.308815),
#  ('crawfbr01', 88.22497),
#  ('stennre01', 88.08099),
#  ('morneju01', 87.95799),
#  ('batisto01', 87.94877),
#  ('dyeje01', 87.89578),
#  ('odorro01', 87.874794),
#  ('bauerha01', 87.87081),
#  ('uribeju01', 87.81962),
#  ('joynewa01', 87.8125),
#  ('polloaj01', 87.80952),
#  ('betanyu01', 87.740746),
#  ('friscfr01', 87.66121),
#  ('mcauldi01', 87.618645),
#  ('cliftha01', 87.59039),
#  ('wrighru01', 87.53156),
#  ('anderge01', 87.38109),
#  ('eatonad02', 87.3615),
#  ('hortowi01', 87.342155),
#  ('giambja01', 87.27423),
#  ('sizemgr01', 87.252914),
#  ('bryankr01', 86.95769),
#  ('bailebo01', 86.917145),
#  ('gonzato01', 86.77655),
#  ('solarya01', 86.74881),
#  ('templga01', 86.688324),
#  ('smallro02', 86.60027),
#  ('gennesc01', 86.58411),
#  ('lawribr01', 86.45783),
#  ('belliro01', 86.43617),
#  ('vottojo01', 86.40547),
#  ('cuddymi01', 86.303635),
#  ('bufordo01', 86.22122),
#  ('panikjo01', 86.12358),
#  ('gantro01', 86.012726),
#  ('abreujo02', 85.8112),
#  ('moustmi01', 85.72534),
#  ('hanfoch01', 85.63806),
#  ('meusebo01', 85.602554),
#  ('critzhu01', 85.60232),
#  ('cimolgi01', 85.44152),
#  ('felizpe01', 85.27348),
#  ('soriaal01', 85.25823),
#  ('holloch01', 85.23854),
#  ('mcmanma01', 85.147446),
#  ('rendoan01', 85.10532),
#  ('dillibo01', 85.09398),
#  ('beltbr01', 84.94229),
#  ('arletbu01', 84.7937),
#  ('lazzeto01', 84.78255),
#  ('mchenau01', 84.7473),
#  ('fostege01', 84.72128),
#  ('grichra01', 84.67363),
#  ('andruel01', 84.53099),
#  ('rodriau01', 84.50188),
#  ('willima04', 84.389175),
#  ('richage01', 84.31234),
#  ('mcmilro01', 84.238075),
#  ('inciaen01', 83.714035),
#  ('kellyji01', 83.6981),
#  ('larkeno01', 83.62175),
#  ('flackma01', 83.41047),
#  ('pradoma01', 83.34619),
#  ('simmoan01', 83.33084),
#  ('lockmwh01', 83.31464),
#  ('kluszte01', 83.24932),
#  ('blackch02', 83.13554),
#  ('saboch01', 82.727066),
#  ('encared01', 82.599655),
#  ('anderga01', 82.53334),
#  ('herreod01', 82.31862),
#  ('duncapa01', 82.16919),
#  ('stripjo01', 82.04846),
#  ('watkige01', 81.629135),
#  ('scutama01', 81.559906),
#  ('grahaja01', 81.498375),
#  ('reverda01', 81.47595),
#  ('gilmogr01', 81.38424),
#  ('oconnda02', 81.268135),
#  ('thameer01', 81.11938),
#  ('garvest01', 80.97961),
#  ('choosh01', 80.85018),
#  ('moneydo01', 80.84149),
#  ('correca01', 80.82754),
#  ('martyjo01', 80.786644),
#  ('gaettga01', 80.74364),
#  ('fieldpr01', 80.694725),
#  ('brownji03', 80.55569),
#  ('hillaa01', 80.54131),
#  ('fischwi01', 80.511024),
#  ('calhoko01', 80.11414),
#  ('webbea01', 80.082855),
#  ('jennide01', 80.05065),
#  ('ascheco01', 79.99815),
#  ('davisal01', 79.78105),
#  ('kubekto01', 79.75487),
#  ('durhale01', 79.6846),
#  ('hrbekke01', 79.63709),
#  ('morgaed01', 79.57096),
#  ('howarfr01', 79.51664),
#  ('knickbi01', 79.398384),
#  ('bettsmo01', 79.39107),
#  ('wrighda03', 79.37587),
#  ('blaloha01', 79.32358),
#  ('conigbi01', 79.21444),
#  ('blairbu01', 79.20221),
#  ('chiozlo01', 79.194725),
#  ('torrejo01', 79.02889),
#  ('plouftr01', 78.99929),
#  ('lindofr01', 78.85919),
#  ('northro01', 78.80114),
#  ('hintoch01', 78.69854),
#  ('goodmbi01', 78.50226),
#  ('jonesru01', 78.265434),
#  ('canhama01', 78.19726),
#  ('escobyu01', 78.077545),
#  ('judniwa01', 78.00534),
#  ('chapmbe01', 77.97339),
#  ('rizzoan01', 77.93905),
#  ('yosted01', 77.66851),
#  ('jollesm01', 77.46579),
#  ('samueju01', 77.46289),
#  ('perezsa02', 77.37349),
#  ('simpsha01', 77.176674),
#  ('ozunama01', 77.14538),
#  ('quinnma01', 77.1248),
#  ('reddijo01', 77.07074),
#  ('scheeal01', 77.020294),
#  ('rosenal01', 76.38657),
#  ('barremi01', 76.25043),
#  ('selphca01', 76.13542),
#  ('browefr01', 76.01142),
#  ('piscost01', 75.80947),
#  ('duffyma01', 75.77092),
#  ('sanomi01', 75.68072),
#  ('bergaau01', 75.38654),
#  ('mercejo03', 75.38374),
#  ('alexada01', 75.31685),
#  ('wongko01', 75.103905),
#  ('blefacu01', 75.02758),
#  ('maierbo01', 74.89602),
#  ('souzast01', 74.79544),
#  ('heathje01', 74.72203),
#  ('springe01', 74.69871),
#  ('baumhfr01', 74.67849),
#  ('polonlu01', 74.6616),
#  ('altuvjo01', 74.54531),
#  ('poseybu01', 74.423134),
#  ('castivi02', 74.23853),
#  ('trumbma01', 74.18048),
#  ('kangju01', 74.136795),
#  ('moseswa01', 73.98122),
#  ('russead02', 73.7565),
#  ('rutlejo01', 73.49125),
#  ('aloufe01', 73.27379),
#  ('decindo01', 72.93031),
#  ('alleyge01', 72.64636),
#  ('mahanar01', 72.50253),
#  ('cansejo01', 72.488945),
#  ('millebr02', 71.94583),
#  ('madlobi01', 71.7664),
#  ('hernaen02', 71.714905),
#  ('swishni01', 71.58311),
#  ('tettlmi01', 71.45177),
#  ('alvarpe01', 71.29117),
#  ('mitchke01', 71.16614),
#  ('paulsbe01', 71.148384),
#  ('croncj01', 70.8953),
#  ('mcgeewi01', 70.80342),
#  ('hartco01', 70.44701),
#  ('realmjt01', 70.306656),
#  ('ramirha01', 70.079735),
#  ('seageco01', 69.9404),
#  ('matsuhi01', 69.843636),
#  ('martihe01', 69.529045),
#  ('thomptr01', 69.44957),
#  ('coxdi01', 69.39857),
#  ('garciad01', 69.21392),
#  ('treshto01', 69.158165),
#  ('seguida01', 69.061386),
#  ('glanvdo01', 68.880325),
#  ('suliker01', 68.81887),
#  ('bayja01', 68.58075),
#  ('kammwi01', 68.34887),
#  ('mcreyke01', 68.198555),
#  ('burnsbi02', 68.132164),
#  ('mahtomi01', 67.953094),
#  ('lollash01', 67.890236),
#  ('stallge02', 67.87931),
#  ('reichhe01', 67.710754),
#  ('mondera01', 67.5868),
#  ('macksh01', 67.37205),
#  ('lefebji01', 67.2068),
#  ('cozarza01', 67.09396),
#  ('freemfr01', 67.032585),
#  ('baldero01', 66.98304),
#  ('duncave01', 66.8405),
#  ('litwhda01', 66.81568),
#  ('byrnemi01', 66.55006),
#  ('unserde01', 66.41973),
#  ('strawda01', 66.4093),
#  ('iguchta01', 66.397285),
#  ('bogaexa01', 66.289474),
#  ('hayesfr01', 65.76815),
#  ('dukesel01', 65.57289),
#  ('piersji01', 65.18836),
#  ('darnatr01', 65.02213),
#  ('gilesbr02', 64.87755),
#  ('baxesji01', 64.79161),
#  ('blairpa01', 64.525154),
#  ('hutchjo01', 64.48964),
#  ('tomasya01', 64.206245),
#  ('pederjo01', 63.943554),
#  ('galaran01', 63.74486),
#  ('smithal04', 63.452076),
#  ('niemabu01', 63.28938),
#  ('palmede01', 63.277946),
#  ('colemed01', 63.247578),
#  ('solerjo01', 63.197655),
#  ('martijd02', 62.897217),
#  ('dirksan01', 62.444542),
#  ('blairfo01', 62.365852),
#  ('orlanpa01', 62.365143),
#  ('altheaa01', 62.360554),
#  ('farreke01', 61.952774),
#  ('radclri01', 61.682274),
#  ('antonjo01', 61.439167),
#  ('brookma01', 61.392426),
#  ('schwaky01', 60.98068),
#  ('boonebr01', 60.57968),
#  ('lansimi01', 60.259533),
#  ('guerrpe01', 60.103935),
#  ('rosared01', 59.79529),
#  ('dykesji01', 59.69841),
#  ('barfije01', 59.2684),
#  ('altmage01', 59.0511),
#  ('hartji01', 58.992313),
#  ('rosarwi01', 58.54402),
#  ('florepa01', 58.43369),
#  ('confomi01', 58.364517),
#  ('pillake01', 58.167416),
#  ('jonesbo01', 58.15773),
#  ('dingeva01', 57.922775),
#  ('laytole01', 57.734955),
#  ('pierzaj01', 57.628662),
#  ('stuardi01', 57.488018),
#  ('clarkgr01', 57.24353),
#  ('scottev01', 56.891613),
#  ('kurowwh01', 56.60423),
#  ('stewash01', 56.465076),
#  ('myerbu01', 56.107212),
#  ('adamsma01', 56.02488),
#  ('marshma01', 55.593277),
#  ('birdgr01', 55.415882),
#  ('thompha02', 55.017193),
#  ('casteni01', 54.866512),
#  ('maddoga01', 54.783398),
#  ('hawksch01', 54.685764),
#  ('burgobi01', 54.627655),
#  ('rigneto01', 54.33112),
#  ('baylodo01', 54.210823),
#  ('durazer01', 53.912395),
#  ('olivehe01', 53.73848),
#  ('freimna01', 53.730835),
#  ('bouchal01', 53.423576),
#  ('lambja01', 53.365856),
#  ('gomezma01', 53.35149),
#  ('grimera01', 53.14564),
#  ('zeileto01', 53.12126),
#  ('grantji02', 53.05731),
#  ('etherbo01', 52.699905),
#  ('moralke01', 52.59671),
#  ('hermaba01', 52.59645),
#  ('allendi01', 52.519207),
#  ('swihabl01', 52.192093),
#  ('santaca01', 52.121017),
#  ('murphbu01', 51.790607),
#  ('cabreal02', 51.772205),
#  ('henlebo01', 51.711445),
#  ('milleha01', 51.551468),
#  ('fullmbr01', 51.510586),
#  ('smolija01', 51.485992),
#  ('shawtr01', 51.24126),
#  ('overbly01', 51.11936),
#  ('riceha01', 51.11152),
#  ('greenji02', 51.01131),
#  ('iglesjo01', 50.881405),
#  ('talbobo01', 50.659214),
#  ('jenkige01', 50.492878),
#  ('outench01', 50.111916),
#  ('oliveto01', 49.852295),
#  ('fostero01', 49.824722),
#  ('mccanja02', 49.736473),
#  ('limmelo01', 49.730446),
#  ('jacobbu02', 49.650845),
#  ('debusad01', 49.534206),
#  ('cohenan01', 49.518085),
#  ('wietema01', 49.462128),
#  ('sipekdi01', 49.421684),
#  ('monrojo01', 49.334003),
#  ('beckhti01', 49.248634),
#  ('tuckepr01', 49.215977),
#  ('versazo01', 49.177773),
#  ('muncyma01', 49.176605),
#  ('thompbo01', 48.86305),
#  ('dolanbi01', 48.594448),
#  ('perezca02', 48.458298),
#  ('ryalru01', 48.436703),
#  ('kennaed02', 48.380474),
#  ('woodjo03', 48.36401),
#  ('susacan01', 48.337395),
#  ('parkeja03', 48.03489),
#  ('tomlike01', 47.92754),
#  ('huffmbe01', 47.78297),
#  ('wilsowi02', 47.75748),
#  ('erickha01', 47.482826),
#  ('herredi01', 47.342354),
#  ('gigonno01', 47.222183),
#  ('carrodi02', 46.95021),
#  ('gatesbr01', 46.856678),
#  ('andersp01', 46.59571),
#  ('evansda01', 46.506844),
#  ('donalja01', 46.42101),
#  ('tosonre01', 46.376305),
#  ('shamsar01', 46.335583),
#  ('posadjo01', 46.31081),
#  ('goebbja01', 46.062355),
#  ('repulri01', 46.02211),
#  ('riosju01', 46.0103),
#  ('northsc01', 46.007683),
#  ('butlebr02', 45.709454),
#  ('holbrsa01', 45.66921),
#  ('hillesh02', 45.543568),
#  ('tracych01', 45.409832),
#  ('zimmero01', 44.834187),
#  ('burbrne01', 44.723614),
#  ('kommefr01', 44.64014),
#  ('hassoge01', 44.46027),
#  ('thomada01', 44.42682),
#  ('davisbr03', 44.374615),
#  ('pompeda01', 44.351936),
#  ('grissma02', 44.278957),
#  ('colesca01', 44.23575),
#  ('ibanera01', 44.07889),
#  ('shillji01', 44.019497),
#  ('piedrjo01', 43.74254),
#  ('gallojo01', 43.71339),
#  ('thomaki01', 43.602924),
#  ('watsoar01', 43.465595),
#  ('bourju01', 43.44306),
#  ('coopeda01', 43.356003),
#  ('matthga01', 43.013645),
#  ('sweenda02', 42.852573),
#  ('masteda01', 42.8315),
#  ('carlyro01', 42.79663),
#  ('cieslte01', 42.560966),
#  ('roonefr01', 42.5565),
#  ('mullemo01', 42.271225),
#  ('jonesja05', 42.25859),
#  ('lipscni01', 42.21752),
#  ('suskope01', 42.081623),
#  ('shaffri01', 42.026062),
#  ('moorean01', 42.01667),
#  ('davidma02', 41.708504),
#  ('davisjo02', 41.703293),
#  ('warneja03', 41.68944),
#  ('banksev01', 41.529663),
#  ('hortoto01', 41.48558),
#  ('collity01', 41.46901),
#  ('rogerja02', 41.45448),
#  ('waderi01', 41.35812),
#  ('koresar01', 41.27017),
#  ('mcgwima01', 41.263992),
#  ('devordo01', 41.168766),
#  ('pillbr01', 40.981815),
#  ('haltose01', 40.968548),
#  ('cedence01', 40.941753),
#  ('marteke01', 40.674072),
#  ('coogada02', 40.64402),
#  ('taylobo01', 40.58676),
#  ('grimmch01', 40.458942),
#  ('gearhga01', 40.38379),
#  ('valenda01', 40.37569),
#  ('yelicch01', 40.191097),
#  ('gubancr01', 40.130867),
#  ('davissp01', 39.982803),
#  ('darincl01', 39.8995),
#  ('stranla01', 39.8806),
#  ('laydope01', 39.686314),
#  ('kisher01', 39.593773),
#  ('batesra01', 39.563534),
#  ('higgike01', 39.55504),
#  ('gantejo01', 39.529495),
#  ('powisca01', 39.51007),
#  ('smithmi02', 39.414642),
#  ('maybejo01', 39.28824),
#  ('irelaha01', 39.26283),
#  ('schneda02', 39.11456),
#  ('sandere01', 39.110832),
#  ('peetech01', 38.987316),
#  ('williha01', 38.843365),
#  ('batesch01', 38.684032),
#  ('travide01', 38.67671),
#  ('purdypi01', 38.646152),
#  ('batesde01', 38.613335),
#  ('bollija01', 38.57967),
#  ('figueje01', 38.56094),
#  ('heimva01', 38.557564),
#  ('bakerfr02', 38.55459),
#  ('denketr01', 38.501804),
#  ('bogente01', 38.483204),
#  ('tyackji01', 38.478657),
#  ('hollimi01', 38.467224),
#  ('schebsc01', 38.45294),
#  ('refsnro01', 38.31966),
#  ('cuccial01', 38.30709),
#  ('pottsjo01', 38.277267),
#  ('murphbi01', 38.25623),
#  ('callale01', 38.171257),
#  ('sloanbr01', 38.16386),
#  ('olsenba01', 38.153065),
#  ('davisbl01', 38.13711),
#  ('ramsebi01', 38.09741),
#  ('tappawa01', 38.033478),
#  ('gladuro01', 37.97788),
#  ('koenele01', 37.970276),
#  ('niehaal01', 37.949444),
#  ('cuthbch01', 37.780045),
#  ('adamsdi01', 37.743824),
#  ('zimmery01', 37.69723),
#  ('langdo01', 37.673923),
#  ('moorega01', 37.65015),
#  ('harvelu01', 37.55581),
#  ('walshau01', 37.426956),
#  ('coffiiv01', 37.40502),
#  ('hoffmdu01', 37.398827),
#  ('drurybr01', 37.38591),
#  ('mallosh01', 37.3618),
#  ('montefe01', 37.33362),
#  ('brownpi01', 37.3269),
#  ('flagewa01', 37.307396),
#  ('laynehi01', 37.293564),
#  ('everito01', 37.277447),
#  ('pikeje01', 37.24168),
#  ('comptmi01', 37.147377),
#  ('lasteto01', 37.0694),
#  ('pintojo01', 36.928635),
#  ('kempma01', 36.9223),
#  ('clarkma02', 36.92117),
#  ('adamsda02', 36.90182),
#  ('meyerge01', 36.75655),
#  ('richiro01', 36.74082),
#  ('delisju01', 36.71846),
#  ('rosarsa01', 36.67448),
#  ('scottle01', 36.627052),
#  ('hodgego01', 36.61035),
#  ('ruary01', 36.55501),
#  ('leathha01', 36.551105),
#  ('antonma01', 36.318268),
#  ('coultch01', 36.26651),
#  ('quellge01', 36.25424),
#  ('britoso01', 36.17838),
#  ('castiru01', 36.15537),
#  ('shortri01', 36.143772),
#  ('taylomi02', 36.12485),
#  ('gregodi01', 36.124603),
#  ('heathsl01', 36.067833),
#  ('thomafr03', 36.061497),
#  ('taveros01', 35.92082),
#  ('lezcasi01', 35.902264),
#  ('stanlji01', 35.87275),
#  ('merrihe01', 35.85826),
#  ('caterda01', 35.851467),
#  ('dunlagr01', 35.787483),
#  ('harpebr02', 35.773426),
#  ('flairal01', 35.70354),
#  ('plessra01', 35.674503),
#  ('wentzst01', 35.610188),
#  ('senerso01', 35.591652),
#  ('phamth01', 35.4583),
#  ('ulisnmi01', 35.40505),
#  ('theobro01', 35.39913),
#  ('wardke01', 35.358097),
#  ('murphto04', 35.327568),
#  ('zuletju01', 35.298862),
#  ('garciam01', 35.285126),
#  ('dappecl01', 35.27624),
#  ('mayersa01', 35.23184),
#  ('hugheto03', 35.199245),
#  ('dudrajo01', 35.185493),
#  ('tayloto01', 35.09952),
#  ('buzasjo01', 35.050945),
#  ('saladty01', 34.99734),
#  ('freeded01', 34.985928),
#  ('cecilda01', 34.958355),
#  ('babinch01', 34.859573),
#  ('roberre01', 34.852364),
#  ('gonzaju03', 34.849014),
#  ('martige01', 34.793808),
#  ('vachete01', 34.771248),
#  ('sherlmo01', 34.742798),
#  ('babelo01', 34.73948),
#  ('peterja01', 34.68841),
#  ('riverca02', 34.669693),
#  ('eastero01', 34.6597),
#  ('bartovi01', 34.580654),
#  ('lukoned01', 34.549145),
#  ('gallajo02', 34.53387),
#  ('gravesi01', 34.50013),
#  ('hancofr01', 34.346546),
#  ('sipinjo01', 34.332577),
#  ('willima08', 34.30603),
#  ('ahmedni01', 34.28829),
#  ('sigmatr01', 34.253086),
#  ('pedrodu01', 34.241558),
#  ('garabed01', 34.153236),
#  ('urshegi01', 34.142597),
#  ('southbi02', 34.0808),
#  ('morelmi01', 34.00904),
#  ('brownwi02', 33.80425),
#  ('lenhado01', 33.77016),
#  ('paulaca01', 33.756157),
#  ('scalebo01', 33.666206),
#  ('kellyjo04', 33.640568),
#  ('willima07', 33.627777),
#  ('ellioha02', 33.574135),
#  ('dobbeda01', 33.546043),
#  ('francma02', 33.51238),
#  ('walteda01', 33.47605),
#  ('bottajo01', 33.303375),
#  ('bensojo01', 33.298798),
#  ('connoto01', 33.278667),
#  ('yatesal01', 33.278004),
#  ('mateoru01', 33.22196),
#  ('coletch01', 33.183575),
#  ('thomabu02', 33.17951),
#  ('castrda01', 33.17645),
#  ('lindsch02', 33.103867),
#  ('flaskro01', 33.090733),
#  ...]

# %%
# A few interesting current players
predict(lstm, ['JoseAltuve', 'GeorgeSpringer', 'AlexBregman', 'CarlosCorrea', 'MichaelBrantley', 'KyleTucker', 'YordanAlvarez', 'AledmysDiaz', 
               'FernandoTatis Jr.', 'ChristianYelich', 'CodyBellinger', 'AnthonyRendon', 'JuanSoto', 'FranciscoLindor', 'PeteAlonso', 'MikeTrout', 'MattChapman'],
       dataset='new')
# Out:
# [('MikeTrout', 95.59606),
#  ('GeorgeSpringer', 94.88754),
#  ('ChristianYelich', 93.80228),
#  ('CodyBellinger', 93.5683),
#  ('PeteAlonso', 88.06546),
#  ('MattChapman', 84.73477),
#  ('FernandoTatis Jr.', 76.16439),
#  ('YordanAlvarez', 47.43093),
#  ('FranciscoLindor', 1.5245372),
#  ('AnthonyRendon', 0.1106233),
#  ('KyleTucker', 0.0724342),
#  ('JuanSoto', 0.03192389),
#  ('AlexBregman', 0.02042448),
#  ('CarlosCorrea', 0.01938864),
#  ('JoseAltuve', 0.018569259),
#  ('AledmysDiaz', 0.016059069),
#  ('MichaelBrantley', 0.013783091)]

# %%
# All players after 2010
predict(lstm, ids_after_2011)
# Out:
# [('FreddieFreeman', 96.52155),
#  ('ToddFrazier', 96.35371),
#  ('KhrisDavis', 96.202),
#  ('BrianDozier', 95.88725),
#  ('KyleSeager', 95.64071),
#  ('MikeTrout', 95.59606),
#  ('PaulGoldschmidt', 95.13227),
#  ('EugenioSuarez', 95.12585),
#  ('GeorgeSpringer', 94.88754),
#  ('WilMyers', 94.72681),
#  ('TrevorStory', 94.48759),
#  ('YoenisCespedes', 94.44325),
#  ('KrisBryant', 94.37288),
#  ('JavierBaez', 94.292206),
#  ('JocPederson', 93.98625),
#  ('YasielPuig', 93.82613),
#  ('ChristianYelich', 93.80228),
#  ('CodyBellinger', 93.5683),
#  ('MookieBetts', 93.119446),
#  ('JoeyGallo', 92.901306),
#  ('KyleSchwarber', 92.85364),
#  ('StevenSouza Jr.', 92.0113),
#  ('AnthonyRizzo', 91.51869),
#  ('RonaldAcuna Jr.', 91.22084),
#  ('YoanMoncada', 91.15048),
#  ('BryceHarper', 90.93375),
#  ('MichaelConforto', 90.65497),
#  ('JasonKipnis', 90.44714),
#  ('MattOlson', 89.90074),
#  ('EvanGattis', 89.635315),
#  ('MikeZunino', 89.29534),
#  ('RhysHoskins', 89.08057),
#  ('BrandonBelt', 88.97232),
#  ('MitchHaniger', 88.14825),
#  ('PeteAlonso', 88.06546),
#  ('DomingoSantana', 87.7234),
#  ('AaronJudge', 86.49916),
#  ('WillsonContreras', 86.28444),
#  ('MiguelSano', 86.27289),
#  ('ShoheiOhtani', 85.74002),
#  ('TreyMancini', 84.77436),
#  ('MattChapman', 84.73477),
#  ('HunterRenfroe', 83.77878),
#  ('JeimerCandelario', 83.77676),
#  ('GarySanchez', 83.117386),
#  ('TimAnderson', 82.96303),
#  ('ChristianWalker', 81.50303),
#  ('MattDavidson', 80.3378),
#  ('Michael A.Taylor', 78.25909),
#  ('JoseAbreu', 77.7524),
#  ('RyanMcMahon', 77.60739),
#  ('TommyPham', 77.53251),
#  ('PaulDeJong', 76.41472),
#  ('FernandoTatis Jr.', 76.16439),
#  ('JorgeAlfaro', 75.04127),
#  ('MichaelChavis', 74.79697),
#  ('WillyAdames', 74.04524),
#  ('AustinRiley', 73.18393),
#  ('IanHapp', 72.45266),
#  ('RonaldGuzman', 71.943275),
#  ('EloyJimenez', 71.942116),
#  ('TeoscarHernandez', 71.917854),
#  ('HernanPerez', 71.85612),
#  ('JoeyButler', 71.2003),
#  ('ScottKingery', 70.53198),
#  ('AlexGuerrero', 70.18297),
#  ('RougnedOdor', 69.957504),
#  ('RyanSchimpf', 69.906845),
#  ('AustinMeadows', 69.754135),
#  ('ByungHoPark', 69.42858),
#  ('KestonHiura', 69.37788),
#  ('BrandonDixon', 69.23184),
#  ('BrianGoodwin', 69.001236),
#  ('Dae-HoLee', 68.82304),
#  ('JuricksonProfar', 68.24487),
#  ('MichaelChoice', 68.19042),
#  ('AristidesAquino', 67.64568),
#  ('RenatoNunez', 67.61612),
#  ('LukeHughes', 66.94607),
#  ('JohnnyField', 66.36819),
#  ('ElliotJohnson', 65.75708),
#  ('PatrickKivlehan', 65.34273),
#  ('NikoGoodrum', 65.28263),
#  ('BrandonLowe', 64.23129),
#  ('JasonPridie', 62.318886),
#  ('KevinNewman', 62.118214),
#  ('TommyJoseph', 61.001472),
#  ('ChristianVillanueva', 56.859856),
#  ('DerekNorris', 56.582855),
#  ('BryanReynolds', 56.31268),
#  ('DavidBote', 55.69655),
#  ('BryanLaHair', 54.48395),
#  ('MarkTrumbo', 54.06308),
#  ('XanderBogaerts', 53.267235),
#  ('MikeYastrzemski', 53.02989),
#  ('DustinFowler', 52.43382),
#  ('LourdesGurriel Jr.', 50.591446),
#  ('JakeMarisnick', 49.54914),
#  ('AllenCordoba', 49.443306),
#  ('JonathanSchoop', 48.966755),
#  ('WillSmith', 48.83734),
#  ('AustinHedges', 48.582188),
#  ('DelinoDeShields', 48.548435),
#  ('YordanAlvarez', 47.43093),
#  ('TommyMedica', 46.567177),
#  ('JeremyHazelbaker', 45.8289),
#  ('RichieMartin', 45.288597),
#  ('KeonBroxton', 44.66894),
#  ('CameronRupp', 44.0004),
#  ('AustinNola', 43.30308),
#  ('JakeCave', 43.252678),
#  ('OscarMercado', 40.530777),
#  ('ChrisOwings', 40.430225),
#  ('JesusGuzman', 40.420532),
#  ('DanielPalka', 40.056667),
#  ('CavanBiggio', 39.036327),
#  ("RyanO'Hearn", 38.71722),
#  ('TylerGoeddel', 38.522305),
#  ('BrettJackson', 38.14705),
#  ('TravisDemeritte', 37.98936),
#  ('Wily MoPena', 37.70454),
#  ('RonnyRodriguez', 37.256214),
#  ('SandyAlcantara', 36.898018),
#  ('JoshNaylor', 36.6653),
#  ('FranmilReyes', 36.286476),
#  ('LucasHarrell', 35.40155),
#  ('TrentGrisham', 35.34077),
#  ('RobelGarcia', 34.721687),
#  ('DannySantana', 34.62437),
#  ('MattBeaty', 34.46938),
#  ('RamonLaureano', 34.366547),
#  ('JakeRogers', 34.246616),
#  ('GarrettHampson', 34.170517),
#  ('ByronBuxton', 34.099674),
#  ('IsanDiaz', 34.076344),
#  ('DerekHolland', 34.013203),
#  ('MarkBuehrle', 33.608986),
#  ('J.D.Martinez', 33.209602),
#  ('NickSenzel', 33.04142),
#  ('RafaelDevers', 32.963474),
#  ('ArchieBradley', 32.863007),
#  ('HaroldCastro', 32.85371),
#  ('YuDarvish', 32.776806),
#  ('FranchyCordero', 32.769703),
#  ('RubbyDe La Rosa', 32.38199),
#  ('AndrewSuarez', 32.117672),
#  ('JonSingleton', 32.059486),
#  ('JoshVanMeter', 31.892967),
#  ('ReneTosoni', 31.873274),
#  ('DinelsonLamet', 31.824707),
#  ('AdrianNieto', 31.760725),
#  ('FranklinMorales', 31.669415),
#  ('StefenRomero', 31.58162),
#  ('CoryLuebke', 31.515642),
#  ('JamesShields', 31.2923),
#  ('MikeBolsinger', 31.2661),
#  ('CarlosVillanueva', 31.265402),
#  ('CarlosTocci', 31.090307),
#  ('ScottKazmir', 31.078482),
#  ('KyleMcClellan', 31.033186),
#  ('AdrianHouser', 31.00845),
#  ('JohnGant', 30.970171),
#  ('KevinSlowey', 30.875053),
#  ('DavidPhelps', 30.849127),
#  ('TylerBeede', 30.794468),
#  ('VinnyRottino', 30.754793),
#  ('AdamHaseley', 30.663353),
#  ('JorgeBonifacio', 30.560911),
#  ('AlexWhite', 30.485594),
#  ('ColinRea', 30.43837),
#  ('JeromeWilliams', 30.427303),
#  ('DustinMoseley', 30.409235),
#  ('WilliamsPerez', 30.394241),
#  ('DustyColeman', 30.361362),
#  ('RobbieErlin', 30.32502),
#  ('RobertStephenson', 30.316124),
#  ('MerrillKelly', 30.276474),
#  ('ChrisPaddack', 30.166964),
#  ('EsmilRogers', 30.164415),
#  ('JeremyGuthrie', 30.11355),
#  ('MattThaiss', 30.090397),
#  ('JeffHoffman', 30.030436),
#  ('ChrisArcher', 30.025816),
#  ('TimStauffer', 29.967043),
#  ('ChadGaudin', 29.92721),
#  ('MattStrahm', 29.917782),
#  ('RafaelMontero', 29.898256),
#  ('CaseyColeman', 29.865587),
#  ('ErikBedard', 29.850805),
#  ('JoseBriceno', 29.816666),
#  ('TyFrance', 29.706049),
#  ('DerrickRobinson', 29.65676),
#  ('BrettAnderson', 29.618227),
#  ('ShaunAnderson', 29.577038),
#  ('RyanStrausborger', 29.472229),
#  ('BradHand', 29.456833),
#  ('ClayBuchholz', 29.417225),
#  ('DavidHale', 29.32352),
#  ('DavidAdams', 29.2833),
#  ('ErvinSantana', 29.282612),
#  ('BubbaStarling', 29.280544),
#  ('RobertoHernandez', 29.225653),
#  ('RobertGsellman', 29.220608),
#  ('JoshVitters', 29.173645),
#  ('BrandonFinnegan', 29.15689),
#  ('YusmeiroPetit', 29.139652),
#  ('EricStamets', 29.134243),
#  ('TravisShaw', 29.072874),
#  ('JulioUrias', 29.05677),
#  ('LuisTorrens', 28.956694),
#  ('TonyCingrani', 28.941895),
#  ('VidalNuno', 28.836138),
#  ('TylerLadendorf', 28.776192),
#  ('AlfredoSimon', 28.766834),
#  ('JordanYamamoto', 28.68781),
#  ('GiftNgoepe', 28.67921),
#  ('MattClark', 28.674868),
#  ('SteveSelsky', 28.661283),
#  ('MarcusStroman', 28.641132),
#  ('ChrisStratton', 28.599829),
#  ('AdalbertoMondesi', 28.581411),
#  ('NickBuss', 28.549545),
#  ('RobSegedin', 28.46629),
#  ('OrlandoCalixte', 28.462708),
#  ('EdwinRios', 28.451591),
#  ('TimAdleman', 28.401958),
#  ('HarrisonBader', 28.387222),
#  ('KevinCron', 28.381697),
#  ('NateLowe', 28.35223),
#  ('TylerMatzek', 28.313911),
#  ('RaiselIglesias', 28.298532),
#  ('SeanHalton', 28.289568),
#  ('DakotaHudson', 28.2731),
#  ('DavidBuchanan', 28.254873),
#  ('BrandonHicks', 28.193491),
#  ('ZackCollins', 28.165579),
#  ('CalQuantrill', 28.020525),
#  ('SethLugo', 27.993404),
#  ('ChrisHeston', 27.950806),
#  ('JacobMay', 27.945099),
#  ('CalebGindl', 27.916393),
#  ('BoBichette', 27.838242),
#  ('MarkLeiter Jr.', 27.751013),
#  ('PeterLambert', 27.697771),
#  ('TaylorJungmann', 27.677164),
#  ('ZelousWheeler', 27.663225),
#  ('DustyBrown', 27.600506),
#  ('AnthonyBemboom', 27.595514),
#  ('AlexMejia', 27.519814),
#  ('BradenBishop', 27.48726),
#  ('JustinNicolino', 27.450735),
#  ('CarlosMoncrief', 27.423513),
#  ('TsuyoshiNishioka', 27.403858),
#  ('CarsonBlair', 27.383575),
#  ('TaijuanWalker', 27.339697),
#  ('MikeSoroka', 27.310545),
#  ('AlexYoung', 27.310219),
#  ('JoshFuentes', 27.263508),
#  ('LukeWeaver', 27.25054),
#  ('StuartTurner', 27.229631),
#  ('KyleLewis', 27.15275),
#  ('CodyClark', 27.147007),
#  ('AlfredoAmezaga', 27.139198),
#  ('TaylorClarke', 27.113836),
#  ('MikeBrosseau', 27.024519),
#  ('FreddyPeralta', 26.96298),
#  ('DylanCozens', 26.94844),
#  ('ArismendyAlcantara', 26.938105),
#  ('WillyGarcia', 26.926548),
#  ('JoshBeckett', 26.89746),
#  ('MattSkole', 26.863543),
#  ('AlexCastellanos', 26.83016),
#  ('SeanBurroughs', 26.718353),
#  ('KyleJensen', 26.69267),
#  ('BrandonWoodruff', 26.675793),
#  ('JavierVazquez', 26.657703),
#  ('NickCiuffo', 26.623),
#  ('AnthonyBass', 26.569658),
#  ('PabloLopez', 26.564444),
#  ('DioryHernandez', 26.522884),
#  ('DarnellSweeney', 26.517244),
#  ('JaycobBrugman', 26.470951),
#  ('CarterKieboom', 26.459208),
#  ('ErisbelArruebarrena', 26.440748),
#  ('KyleKubitza', 26.384035),
#  ('AdamDuvall', 26.323084),
#  ('TrayvonRobinson', 26.309528),
#  ('KyleHudson', 26.257442),
#  ('BrockStassi', 26.202625),
#  ('SamHilliard', 26.185852),
#  ('DylanMoore', 26.172935),
#  ('DontrelleWillis', 26.147064),
#  ('OscarHernandez', 26.125416),
#  ('KelvinGutierrez', 26.062445),
#  ('MaxFried', 26.047104),
#  ('JonathanPettibone', 25.99713),
#  ('ChadPinder', 25.987112),
#  ('BradenShipley', 25.954142),
#  ('RyanCordell', 25.923521),
#  ('LaneAdams', 25.891117),
#  ('DannyMuno', 25.875124),
#  ('ChrisShaw', 25.873398),
#  ('HectorGomez', 25.848997),
#  ('EdwinMaysonet', 25.803726),
#  ('CoreyBrown', 25.776896),
#  ('DomNunez', 25.773298),
#  ('ClintRobinson', 25.759119),
#  ('HectorGimenez', 25.749123),
#  ('NickNoonan', 25.680828),
#  ("TylerO'Neill", 25.666756),
#  ('BrockPeterson', 25.60802),
#  ('YonathanDaza', 25.566296),
#  ('DestinHood', 25.482222),
#  ('CarlosTriunfel', 25.455114),
#  ('MauroGomez', 25.325102),
#  ('MarkHamilton', 25.260656),
#  ('RangelRavelo', 25.255054),
#  ('DannyMendick', 25.208586),
#  ('NeftaliSoto', 25.153164),
#  ('WilliCastro', 25.05321),
#  ('ShanePeterson', 25.01373),
#  ('DeanAnna', 24.949669),
#  ('FranciscoArcia', 24.915302),
#  ('JonathanDiaz', 24.905159),
#  ('YairoMunoz', 24.847658),
#  ('LewFord', 24.839006),
#  ('TonyRenda', 24.804466),
#  ('ErickAlmonte', 24.792685),
#  ('BenLively', 24.77343),
#  ('DomingoLeyba', 24.77224),
#  ('XavierAvery', 24.752525),
#  ('ChrisMcGuiness', 24.749039),
#  ('NickDini', 24.724344),
#  ('KyleGarlick', 24.693493),
#  ('RayOlmedo', 24.668629),
#  ('JohnAndreoli', 24.622507),
#  ('JesmuelValentin', 24.567873),
#  ('NickGreen', 24.554497),
#  ('AnthonyAlford', 24.426092),
#  ('GuillermoQuiroz', 24.358677),
#  ('CedricHunter', 24.333748),
#  ('ColinWalsh', 24.333534),
#  ('KylePhillips', 24.320122),
#  ('DarielAlvarez', 24.241465),
#  ('MicahJohnson', 24.229889),
#  ('TravisTaijeron', 24.209095),
#  ('JamesDarnell', 24.208868),
#  ('JaredWalsh', 24.205048),
#  ('AdamLoewen', 24.187027),
#  ('RyderJones', 24.148699),
#  ("BrianO'Grady", 24.133053),
#  ('SladeHeathcott', 24.09413),
#  ('RussCanzler', 24.086472),
#  ('YormanRodriguez', 24.066832),
#  ('NicoHoerner', 24.053726),
#  ('GavinLux', 24.01062),
#  ('AllanDykstra', 23.99226),
#  ('LaneThomas', 23.967657),
#  ('YuChang', 23.958843),
#  ('ThairoEstrada', 23.953447),
#  ('DougBernier', 23.951216),
#  ('BrianBixler', 23.943579),
#  ('LuisMartinez', 23.934866),
#  ('StevieWilkerson', 23.907045),
#  ('RyanCourt', 23.853401),
#  ('MikeFord', 23.846493),
#  ('NateOrf', 23.842373),
#  ('BlakeDavis', 23.832233),
#  ('ErikKomatsu', 23.814224),
#  ('JackReinheimer', 23.760447),
#  ('LukeMontz', 23.74436),
#  ('BradEmaus', 23.734697),
#  ('LuisPerdomo', 23.732382),
#  ('BeauTaylor', 23.724737),
#  ('BrentSuter', 23.637148),
#  ('DannyDorn', 23.635096),
#  ('MiguelGomez', 23.555004),
#  ('ErickMejia', 23.550226),
#  ('CameronPerkins', 23.498772),
#  ('RafaelBautista', 23.478186),
#  ('MikeWilson', 23.472967),
#  ('Jae-GyunHwang', 23.461695),
#  ('StevenBrault', 23.432539),
#  ('SheldonNeuse', 23.417255),
#  ('ReyNavarro', 23.288685),
#  ('BrendanRodgers', 23.280817),
#  ('JeffKobernus', 23.232824),
#  ('FranciscoPeguero', 23.196753),
#  ('HumbertoArteaga', 23.128792),
#  ('AbrahamToro', 22.99113),
#  ('EngelBeltre', 22.987535),
#  ('AlbertoRosario', 22.923111),
#  ('JoeMahoney', 22.8613),
#  ('JohnnyMonell', 22.854713),
#  ('SethMejias-Brean', 22.825897),
#  ('JoeBenson', 22.808926),
#  ('JuanGraterol', 22.795683),
#  ('GilVelazquez', 22.763609),
#  ('JeradHead', 22.717352),
#  ('MattYoung', 22.655968),
#  ('MarkZagunis', 22.654516),
#  ('RyanAdams', 22.548904),
#  ('PhillipErvin', 22.52218),
#  ('BradleyZimmer', 22.507969),
#  ('JakeFraley', 22.353502),
#  ('MikeOlt', 22.326395),
#  ('CorbanJoseph', 22.27984),
#  ('KensukeTanaka', 22.242115),
#  ('DavidFreitas', 22.241308),
#  ('BrianDinkelman', 22.141405),
#  ('BobbyBradley', 22.083378),
#  ('NickKingham', 22.081635),
#  ('SeanMurphy', 22.063288),
#  ('AustinAllen', 22.04687),
#  ('GavinCecchini', 21.964268),
#  ('AndrewKnizner', 21.865305),
#  ('JordanyValdespin', 21.830881),
#  ('JaylinDavis', 21.826384),
#  ('JackMayfield', 21.76043),
#  ('HernanIribarren', 21.715221),
#  ('JasonMartin', 21.67984),
#  ('ChristopherBostick', 21.579288),
#  ('ZachLutz', 21.567223),
#  ('JonathanVillar', 21.446028),
#  ('OscarTaveras', 21.370388),
#  ('GleyberTorres', 20.878115),
#  ('ZackGranite', 20.874968),
#  ('JasonCoats', 20.863722),
#  ('ElianHerrera', 20.693195),
#  ('MauricioDubon', 20.64038),
#  ('SpencerKieboom', 20.620207),
#  ('PhillipEvans', 20.586344),
#  ('MattHague', 20.413313),
#  ('GarrettStubbs', 20.332067),
#  ('GarinCecchini', 20.307207),
#  ('OswaldoArcia', 20.292189),
#  ('MikeMarjama', 20.278479),
#  ('AdrianCardenas', 20.085953),
#  ('JoseTrevino', 20.007818),
#  ('Luis AntonioRodriguez', 19.892586),
#  ('StevenDuggar', 19.707241),
#  ('JakeGoebbert', 19.691904),
#  ('ZachWalters', 19.679045),
#  ('JakeBauers', 19.597763),
#  ('RyanMcBroom', 19.497805),
#  ('ShedLong Jr.', 19.424421),
#  ('LaMonteWade Jr', 19.379139),
#  ('HectorOlivera', 19.365564),
#  ('DustinPeterson', 19.182726),
#  ('JeremyHefner', 19.15676),
#  ('SonnyGray', 19.075874),
#  ('ZachEflin', 19.031773),
#  ('JoseUrena', 19.002733),
#  ('JoshRojas', 18.774687),
#  ('SalRomano', 18.759659),
#  ('JamesMcDonald', 18.75918),
#  ('MattAngle', 18.62467),
#  ('JoeyLucchesi', 18.580774),
#  ('NoelCuevas', 18.493118),
#  ('TyBlach', 18.367668),
#  ('MilesMikolas', 18.305536),
#  ('ScottHeineman', 18.180952),
#  ('TylerAustin', 18.095177),
#  ('IldemaroVargas', 17.674767),
#  ('WilfredoTovar', 17.328888),
#  ('JuanNicasio', 17.178223),
#  ('BrettEibner', 17.17451),
#  ('RioRuiz', 16.965298),
#  ('JacobTurner', 16.908587),
#  ('CharlieCulberson', 16.876442),
#  ('RowdyTellez', 16.727945),
#  ('KyleFarmer', 16.599543),
#  ('EuryPerez', 16.57095),
#  ('NickSolak', 16.55531),
#  ('YanGomes', 16.489134),
#  ('JoeMusgrove', 16.420023),
#  ('BillyMcKinney', 16.28705),
#  ('WalkerBuehler', 16.265423),
#  ('AdamConley', 16.254313),
#  ('JasonVargas', 16.227562),
#  ('MikieMahtook', 16.16744),
#  ('LuisRengifo', 15.963592),
#  ('TimLopes', 15.802378),
#  ('SeanNewcomb', 15.662834),
#  ('EricLauer', 15.542997),
#  ('MattMoore', 15.5088),
#  ('MattWisler', 15.455125),
#  ('JohnMayberry Jr.', 15.436879),
#  ('DallasKeuchel', 15.171676),
#  ('BrandonBeachy', 15.101397),
#  ('JoseFernandez', 14.643218),
#  ('JorgeSoler', 14.462338),
#  ('DrewPomeranz', 14.384598),
#  ('DougFister', 14.182824),
#  ('StevenMoya', 13.811585),
#  ('TylerMahle', 13.8113575),
#  ('AndrewKnapp', 13.78981),
#  ('Wei-YinChen', 13.282185),
#  ('SethBrown', 13.08943),
#  ('AaronAltherr', 13.066734),
#  ('RossDetwiler', 12.8942175),
#  ('TrevorRichards', 12.751248),
#  ('TyKelly', 12.644905),
#  ('AlexLiddi', 12.617847),
#  ('MattAdams', 12.554026),
#  ('RamonFlores', 12.252346),
#  ('CalebSmith', 12.130824),
#  ('DrewRobinson', 12.035637),
#  ('HendersonAlvarez III', 11.894338),
#  ('PatValaika', 11.719127),
#  ('BenGamel', 11.6272955),
#  ('DannyJansen', 11.248865),
#  ('MikeMontgomery', 11.076268),
#  ('RandallDelgado', 10.752602),
#  ('JesusFlores', 10.714935),
#  ('RossStripling', 10.432645),
#  ('Jose MiguelFernandez', 10.315275),
#  ('JTRiddle', 10.168126),
#  ('RaffyLopez', 9.973823),
#  ('DereckRodriguez', 9.842789),
#  ('ChristianFriedrich', 9.77687),
#  ('JoeKelly', 9.68493),
#  ('JakePeavy', 9.653761),
#  ('ZackGodley', 9.335022),
#  ('RusneyCastillo', 9.009253),
#  ('ScottFeldman', 8.90441),
#  ('AJReed', 8.8620205),
#  ('JuniorGuerra', 8.743276),
#  ('LewisBrinson', 8.66849),
#  ('GraysonGreiner', 8.391508),
#  ('FranciscoPena', 8.356466),
#  ('OdrisamerDespaigne', 8.008164),
#  ('JackFlaherty', 7.9701147),
#  ('JuniorLake', 7.815186),
#  ('NickyDelmonico', 7.5552316),
#  ('ChrisRusin', 7.358335),
#  ('NateFreiman', 7.311859),
#  ('LukeVoit', 6.627908),
#  ('BartoloColon', 6.6057725),
#  ('TommyEdman', 6.5831532),
#  ('JimmyNelson', 6.547622),
#  ('TomasNido', 6.4593525),
#  ('L.J.Hoes', 6.4545646),
#  ('YasmanyTomas', 6.4375267),
#  ('KyleParker', 5.946176),
#  ('NathanEovaldi', 5.5790954),
#  ('ColeTucker', 5.551854),
#  ('AustinWynns', 5.227662),
#  ('AdamMorgan', 4.589836),
#  ('RogerKieschnick', 4.5882134),
#  ("ShawnO'Malley", 4.5182443),
#  ('TerranceGore', 4.3524523),
#  ('QuintinBerry', 4.300457),
#  ('AramisGarcia', 4.209248),
#  ('AntonioSenzatela', 4.1999555),
#  ('PrestonTucker', 4.1340017),
#  ('IvanNova', 4.099886),
#  ('KevinKramer', 4.0303698),
#  ('KyleFreeland', 3.980649),
#  ('MeibrysViloria', 3.9742908),
#  ('MattReynolds', 3.8559422),
#  ('RichHill', 3.7380762),
#  ('TylerMoore', 3.7158768),
#  ('VladimirGuerrero Jr.', 3.5518825),
#  ('DerekFisher', 3.523301),
#  ('MikeNickeas', 3.454254),
#  ('BlakeTekotte', 3.4371278),
#  ('TylerAnderson', 3.4339645),
#  ('EdLucas', 3.3169184),
#  ('BreyvicValera', 3.3098586),
#  ('AdronChambers', 3.2333677),
#  ('TrevorWilliams', 3.2069154),
#  ('JeradEickhoff', 3.1973157),
#  ('CordPhelps', 3.1497598),
#  ('AaronHicks', 2.9978185),
#  ('BoogPowell', 2.95413),
#  ('JakeLamb', 2.7898092),
#  ('WilinRosario', 2.7039795),
#  ('JeffBianchi', 2.687156),
#  ('JamesonTaillon', 2.6655796),
#  ('JohnLackey', 2.5326943),
#  ('OmarQuintanilla', 2.517319),
#  ('MannyMachado', 2.4929798),
#  ('RamonCabrera', 2.4541435),
#  ('BrettPhillips', 2.4455466),
#  ('NolanArenado', 2.4338114),
#  ('CristhianAdames', 2.3709881),
#  ('ClintFrazier', 2.2751064),
#  ('WillMiddlebrooks', 2.2070804),
#  ('KyleHigashioka', 2.1111422),
#  ('ChrisMarrero', 2.105215),
#  ('MikeTauchman', 2.0990508),
#  ('MarkCanha', 2.0589852),
#  ('RosellHerrera', 2.050413),
#  ('CleteThomas', 2.048337),
#  ('OrlandoArcia', 2.0348992),
#  ('J.D.Davis', 2.0122194),
#  ('JosmilPinto', 1.9851584),
#  ('JoseQuintana', 1.8413378),
#  ('StevenMatz', 1.8299356),
#  ('Ji-ManChoi', 1.8252912),
#  ('MikeFiers', 1.8011401),
#  ('TylerWhite', 1.7315365),
#  ('TaylorWard', 1.6362784),
#  ('EricStults', 1.6256803),
#  ('Tzu-WeiLin', 1.5965803),
#  ('ChrisCapuano', 1.5573894),
#  ('JimmyParedes', 1.5393798),
#  ('FranciscoLindor', 1.5245372),
#  ('MikeFreeman', 1.4676055),
#  ('PatrickWisdom', 1.4621934),
#  ('AustinDean', 1.4583122),
#  ('JerrySands', 1.4353185),
#  ('JamesJones', 1.4323035),
#  ('JasonRogers', 1.3441672),
#  ('LoganWatkins', 1.3421105),
#  ('JoeyTerdoslavich', 1.3293444),
#  ('CedricMullins', 1.318017),
#  ('JohnHicks', 1.2989593),
#  ('IsaacGalloway', 1.2970827),
#  ('TonySanchez', 1.2951274),
#  ('DarinMastroianni', 1.2876469),
#  ('GermanMarquez', 1.2828096),
#  ('AlexWood', 1.2758287),
#  ('DevenMarrero', 1.2690657),
#  ('MikeGerber', 1.2330292),
#  ('BenPaulsen', 1.2153529),
#  ('KennysVargas', 1.2150255),
#  ('DanStraily', 1.1669618),
#  ('TylerSaladino', 1.15252),
#  ('TrevorBrown', 1.1416332),
#  ('WilkinRamirez', 1.1316302),
#  ('JackHannahan', 1.118842),
#  ('KevinGausman', 1.1043345),
#  ('DwightSmith', 1.0910866),
#  ('WillieCalhoun', 1.0499698),
#  ('TrevorCahill', 1.0202166),
#  ('RichieShaffer', 1.0098463),
#  ('AlfredoMarte', 0.9794836),
#  ('FranciscoMejia', 0.9761229),
#  ('CarlosPeguero', 0.97217065),
#  ('PeteOrr', 0.9515469),
#  ('ZoiloAlmonte', 0.9163443),
#  ('EddieRosario', 0.8902897),
#  ('AlexBlandino', 0.8825529),
#  ('RymerLiriano', 0.8600655),
#  ('MarcoEstrada', 0.8326764),
#  ('TimBeckham', 0.83110464),
#  ('AdamEngel', 0.79551953),
#  ('HunterDozier', 0.7699974),
#  ('Luis AlfonsoCruz', 0.74167055),
#  ('GregBird', 0.7379316),
#  ('DonaldLutz', 0.7371825),
#  ('RandalGrichuk', 0.7361588),
#  ('A.J.Burnett', 0.6958986),
#  ('OzzieAlbies', 0.69258356),
#  ('CarsonKelly', 0.67438275),
#  ('AlexVerdugo', 0.65658575),
#  ('AndrewBrown', 0.6529125),
#  ('KirkNieuwenhuis', 0.65249467),
#  ('AndyWilkins', 0.645361),
#  ('JaredHoying', 0.63638544),
#  ('RafaelYnoa', 0.63297284),
#  ('TaylorGreen', 0.6190649),
#  ('MylesStraw', 0.564875),
#  ('DavidLough', 0.55892724),
#  ('CarlosPerez', 0.545964),
#  ('AlenHanson', 0.5430904),
#  ('JustinRuggiano', 0.5404078),
#  ('HenryUrrutia', 0.5398926),
#  ('JacePeterson', 0.5197892),
#  ('BryceBrentz', 0.5189944),
#  ('JoseOsuna', 0.5163477),
#  ('IrvingFalu', 0.49012503),
#  ('MichaelPerez', 0.4884386),
#  ('DominicSmith', 0.45344913),
#  ('JonBerti', 0.4509082),
#  ('ColeFigueroa', 0.45043626),
#  ('TomKoehler', 0.43191513),
#  ('TaylorFeatherston', 0.41534203),
#  ('JonGray', 0.40535447),
#  ('TylerFlowers', 0.39039016),
#  ('LeonysMartin', 0.3787069),
#  ('FernandoMartinez', 0.36928183),
#  ('StephenCardullo', 0.34884),
#  ('NickAhmed', 0.3485527),
#  ('ChristinStewart', 0.3408233),
#  ('MatGamel', 0.33444342),
#  ('ChrisColabello', 0.33021808),
#  ('JeffLocke', 0.32898676),
#  ('LuisGuillorme', 0.32477847),
#  ('MarcKrauss', 0.31701562),
#  ('MaxStassi', 0.30569953),
#  ('ChadKuhl', 0.30563533),
#  ('ChadWallach', 0.30258304),
#  ('DillonGee', 0.29765576),
#  ('DavidCooper', 0.2974362),
#  ('CharlieTilson', 0.29389843),
#  ('JacobStallings', 0.2927994),
#  ('PabloReyes', 0.28989354),
#  ('ReeseMcGuire', 0.28456104),
#  ('DarrellCeciliani', 0.28129926),
#  ('BlakeSwihart', 0.27305174),
#  ('JoseRamirez', 0.27036718),
#  ('NickPivetta', 0.26171806),
#  ('AustinHays', 0.25518787),
#  ('BrettNicholas', 0.25027013),
#  ('EzequielCarrera', 0.24756102),
#  ('WelingtonCastillo', 0.24075587),
#  ('LuisJimenez', 0.23177555),
#  ('CliffLee', 0.23137587),
#  ('JhonatanSolano', 0.22788641),
#  ('TylerPastornicky', 0.22784804),
#  ('ZachDavies', 0.22465397),
#  ('MitchGarver', 0.22442801),
#  ('T.J.Rivera', 0.22366385),
#  ('AvisailGarcia', 0.22239096),
#  ('AnthonySantander', 0.22226149),
#  ('ShaunMarcum', 0.21885422),
#  ('KoleCalhoun', 0.21291006),
#  ('ChadBettis', 0.20854263),
#  ('BrandonBarnes', 0.20084593),
#  ('HaroldRamirez', 0.19793822),
#  ('ToddCunningham', 0.1934635),
#  ('JesseWinker', 0.1921045),
#  ('ErikGonzalez', 0.18731369),
#  ('JoeyRickard', 0.18480407),
#  ('DawelLugo', 0.18145761),
#  ('DJStewart', 0.18124646),
#  ('AlexDickerson', 0.18082744),
#  ('NoahSyndergaard', 0.17917602),
#  ('RyanFlaherty', 0.17558224),
#  ('MaxMuncy', 0.17401966),
#  ('CorySpangenberg', 0.17023149),
#  ('TysonRoss', 0.16671789),
#  ('RamonTorres', 0.1596179),
#  ('ChristianBethancourt', 0.15906958),
#  ('XavierScruggs', 0.14102161),
#  ('BrianAnderson', 0.13817137),
#  ('YadielRivera', 0.13528399),
#  ('JustinChristian', 0.12955718),
#  ('JackieBradley Jr.', 0.12928367),
#  ('CharlieBlackmon', 0.12823953),
#  ('ShelbyMiller', 0.12776823),
#  ('EndyChavez', 0.122040175),
#  ('WilyPeralta', 0.1165711),
#  ('BruceMaxwell', 0.11510409),
#  ('JeddGyorko', 0.11362351),
#  ('EricCampbell', 0.1108708),
#  ('AnthonyRendon', 0.1106233),
#  ('LuisUrias', 0.108859174),
#  ('MichaelHermosillo', 0.103684165),
#  ('MaxKepler', 0.10114829),
#  ('JordanDanks', 0.09930308),
#  ('JulioTeheran', 0.09677417),
#  ('RobbieRay', 0.09619766),
#  ('LanceLynn', 0.09609286),
#  ('EdinsonVolquez', 0.09411806),
#  ('JoeyWendle', 0.09269782),
#  ('DaltonPompey', 0.092039645),
#  ('RyanLaMarre', 0.09128855),
#  ('MikeFoltynewicz', 0.09055704),
#  ('LeuryGarcia', 0.09023724),
#  ('YandyDiaz', 0.09001327),
#  ('JarrettParker', 0.086872645),
#  ('RichardUrena', 0.08506175),
#  ('NickMartini', 0.083522476),
#  ('KentaMaeda', 0.0822904),
#  ('TylerNaquin', 0.08228547),
#  ('TylerChatwood', 0.08227002),
#  ('MaxMoroff', 0.07877636),
#  ('ReneRivera', 0.07808454),
#  ('DarinRuf', 0.07699402),
#  ('JonathanDavis', 0.07636983),
#  ('DixonMachado', 0.07589849),
#  ('TrayceThompson', 0.0753116),
#  ('AndrewBenintendi', 0.0746455),
#  ('FranklinBarreto', 0.07394475),
#  ('JordanZimmermann', 0.07370182),
#  ('KyleTucker', 0.0724342),
#  ('CesarPuello', 0.07139086),
#  ('VanceWorley', 0.071324125),
#  ('Hyun JinRyu', 0.07066483),
#  ('TaylorMotter', 0.067450546),
#  ('WadeMiley', 0.06725265),
#  ('GerritCole', 0.067127176),
#  ('GorkysHernandez', 0.065183975),
#  ('ChrisParmelee', 0.063616),
#  ('WilliansAstudillo', 0.0633811),
#  ('JabariBlash', 0.06310639),
#  ('JordanLuplow', 0.06282886),
#  ('J.P.Crawford', 0.062209595),
#  ('CalebJoseph', 0.06181355),
#  ('BrandonSnyder', 0.0617423),
#  ('JefryMarte', 0.06132463),
#  ('BrandonNimmo', 0.061254553),
#  ('GarrettCooper', 0.06124579),
#  ('AndrewSusac', 0.061093956),
#  ('RobinsonChirinos', 0.06075867),
#  ('AndrewStevenson', 0.06014466),
#  ('JasonMarquis', 0.06009891),
#  ('SandyLeon', 0.060018618),
#  ('IvanDe Jesus Jr.', 0.059543427),
#  ('RyanRua', 0.05934437),
#  ('MaxScherzer', 0.059337772),
#  ('AustinRomine', 0.05839533),
#  ('MarcellOzuna', 0.05794756),
#  ('RyanGoins', 0.057778683),
#  ('LoganSchafer', 0.057687342),
#  ('DevonTravis', 0.05616757),
#  ('JoshCollmenter', 0.055956926),
#  ('MikeMinor', 0.055839527),
#  ('JeremyHellickson', 0.055687096),
#  ('AnthonyDeSclafani', 0.055578496),
#  ('JoeRoss', 0.054575242),
#  ('CarlosMartinez', 0.05424985),
#  ('MasonWilliams', 0.053891893),
#  ('RaimelTapia', 0.05330851),
#  ('JettBandy', 0.05326962),
#  ('EricHosmer', 0.052765694),
#  ('RyanWheeler', 0.052718487),
#  ('JonLester', 0.052328587),
#  ('CodyAsche', 0.052294765),
#  ('MunenoriKawasaki', 0.052044682),
#  ('CheslorCuthbert', 0.051527426),
#  ('RobertoPerez', 0.05093014),
#  ('MiguelAndujar', 0.050126243),
#  ('VictorCaratini', 0.05009123),
#  ('CarlosAsuaje', 0.04977854),
#  ('AndrewCashner', 0.04967734),
#  ('JesusMontero', 0.04923041),
#  ('GioUrshela', 0.048768066),
#  ('DanielCastro', 0.048532),
#  ('AbrahamAlmonte', 0.047678493),
#  ('JoshPhegley', 0.047500033),
#  ('TylerHolt', 0.047385927),
#  ('TomMurphy', 0.04666479),
#  ('ScottSchebler', 0.046127975),
#  ('AdonisGarcia', 0.046099376),
#  ('EfrenNavarro', 0.04567058),
#  ('HanserAlberto', 0.04556494),
#  ('JesusAguilar', 0.04504759),
#  ('JoseConstanza', 0.044752117),
#  ('BrettPill', 0.04453727),
#  ('JordanSchafer', 0.043635976),
#  ('AndrewRomine', 0.043185785),
#  ("PeterO'Brien", 0.043064285),
#  ('CollinCowgill', 0.042780694),
#  ('RyanVogelsong', 0.042748913),
#  ('MattCarpenter', 0.0426834),
#  ('TylerCollins', 0.042643543),
#  ('NickFranklin', 0.04195243),
#  ('MarcoHernandez', 0.0418093),
#  ('ChanceSisco', 0.041577213),
#  ('MartinMaldonado', 0.040990476),
#  ('ChristianArroyo', 0.040975764),
#  ('PedroSeverino', 0.04043001),
#  ("Chased'Arnaud", 0.039768923),
#  ('LonnieChisenhall', 0.039758664),
#  ('JeffSamardzija', 0.039746802),
#  ('StephenStrasburg', 0.039627515),
#  ('BrandonLaird', 0.03954679),
#  ("Travisd'Arnaud", 0.038919445),
#  ('CoreySeager', 0.038573068),
#  ('JoseRondon', 0.038404837),
#  ('YasmaniGrandal', 0.038104698),
#  ('MannyPina', 0.038052626),
#  ('FranciscoLiriano', 0.037959404),
#  ('WilmerDifo', 0.037713584),
#  ('ManuelMargot', 0.037576087),
#  ('AndrewToles', 0.03749959),
#  ('CurtCasali', 0.037392516),
#  ('GioGonzalez', 0.037248015),
#  ('BrandonDrury', 0.037050825),
#  ('AdrianSanchez', 0.03699208),
#  ('KyleHendricks', 0.036985073),
#  ('DilsonHerrera', 0.036957413),
#  ('JoshSatin', 0.03663818),
#  ('ScottVan Slyke', 0.03627766),
#  ('SteveLombardozzi', 0.036215805),
#  ('TreaTurner', 0.03614846),
#  ('Juan CarloPerez', 0.036113698),
#  ('CamGallagher', 0.036108673),
#  ('AustinSlater', 0.035696317),
#  ('C.J.Cron', 0.035467483),
#  ('TommyField', 0.035408005),
#  ('DerekDietrich', 0.035256207),
#  ('AaronNola', 0.035205815),
#  ('MichaelLorenzen', 0.035166882),
#  ('ChristianVazquez', 0.034884382),
#  ('JordanLyles', 0.034725275),
#  ('JoshRutledge', 0.034422368),
#  ('DanielVogelbach', 0.03430667),
#  ('MagneurisSierra', 0.034154616),
#  ('VinceVelasquez', 0.034025755),
#  ('JustinSellers', 0.033701643),
#  ('EliasDiaz', 0.033683684),
#  ('JordanPacheco', 0.033652242),
#  ('ChaseAnderson', 0.03349552),
#  ('EmmanuelBurriss', 0.033232123),
#  ('MoisesSierra', 0.03321423),
#  ('MarcusSemien', 0.033187196),
#  ('JakeArrieta', 0.032887477),
#  ('JuanSoto', 0.03192389),
#  ('TannerRoark', 0.031793952),
#  ('SamTravis', 0.031774953),
#  ('LuisSardinas', 0.031631175),
#  ('MichaelWacha', 0.03157537),
#  ('Hyun SooKim', 0.031550996),
#  ('MichaelMcKenry', 0.03147361),
#  ('RyonHealy', 0.031309545),
#  ('DevinMesoraco', 0.031298205),
#  ('AmedRosario', 0.03108896),
#  ('BillyHamilton', 0.030512663),
#  ('ZackWheeler', 0.030458948),
#  ('KevanSmith', 0.03027652),
#  ('DaveSappelt', 0.030077431),
#  ('MattDominguez', 0.030073047),
#  ('AndrewLambo', 0.029955894),
#  ('PedroCiriaco', 0.029629279),
#  ('CarlosCorporan', 0.029588459),
#  ('NickCastellanos', 0.029302591),
#  ('John RyanMurphy', 0.029247275),
#  ('JemileWeeks', 0.029201582),
#  ('JimAdduci', 0.029194064),
#  ('MichaelTaylor', 0.029134005),
#  ('PeteKozma', 0.029088708),
#  ('JakeSmolinski', 0.02908674),
#  ('BrandonMcCarthy', 0.028907761),
#  ('MattGarza', 0.028566306),
#  ('JustinBour', 0.028401142),
#  ('AnthonyRecker', 0.028297838),
#  ('GrantGreen', 0.028255835),
#  ('GregorioPetit', 0.028062),
#  ('PatrickCorbin', 0.02794597),
#  ('RonaldTorreyes', 0.027810942),
#  ('VictorRobles', 0.027777238),
#  ('ReyFuentes', 0.027713962),
#  ('WilmerFlores', 0.027407968),
#  ('JuanCenteno', 0.027232928),
#  ('KevinPlawecki', 0.027030205),
#  ('LukeMaile', 0.026609119),
#  ('JoseLobaton', 0.02626234),
#  ('PauloOrlando', 0.026113803),
#  ('HectorSanchez', 0.026063858),
#  ('ChrisHerrmann', 0.02587958),
#  ('ColinMoran', 0.0257593),
#  ('RobBrantly', 0.02573345),
#  ('GuillermoHeredia', 0.02562785),
#  ('PedroFlorimon', 0.025608188),
#  ('NickyLopez', 0.025363473),
#  ('JohnnyGiavotella', 0.025101947),
#  ('TimFederowicz', 0.02506815),
#  ('MattSzczur', 0.02479503),
#  ('DonovanSolano', 0.024684802),
#  ('MattDuffy', 0.024498306),
#  ('RyanLavarnway', 0.024434788),
#  ('TonyKemp', 0.024351016),
#  ('TonyCampana', 0.02434716),
#  ('SteveClevenger', 0.024156768),
#  ('RafaelOrtega', 0.024127651),
#  ('MattHarvey', 0.024086),
#  ('NickWilliams', 0.024041884),
#  ('Jung HoKang', 0.02391942),
#  ('AndyParrino', 0.023851192),
#  ('SocratesBrito', 0.023767471),
#  ('TylerWade', 0.02368357),
#  ('JBShuck', 0.023559405),
#  ('JacobdeGrom', 0.023526544),
#  ('PhilGosselin', 0.023346618),
#  ('LuisArraez', 0.023338785),
#  ('JaffDecker', 0.023334645),
#  ('DavidDahl', 0.02310621),
#  ('ZackGreinke', 0.022908412),
#  ('MattMcBride', 0.022850342),
#  ('TonyCruz', 0.022799438),
#  ('AddisonRussell', 0.022678547),
#  ('DustinGarneau', 0.022419546),
#  ('MichaelMartinez', 0.022323027),
#  ('OdubelHerrera', 0.022269243),
#  ('JesusSucre', 0.022222174),
#  ('BrettLawrie', 0.022170708),
#  ('J.T.Realmuto', 0.022145145),
#  ('KelbyTomlinson', 0.022144955),
#  ('ChristianColon', 0.022140265),
#  ('TuffyGosewisch', 0.021946613),
#  ('ShaneRobinson', 0.02169576),
#  ('TomasTelis', 0.021676093),
#  ('IsiahKiner-Falefa', 0.021527512),
#  ('BryanHoladay', 0.02150806),
#  ('KalebCowart', 0.021487156),
#  ('Matthewden Dekker', 0.021049153),
#  ('KristopherNegron', 0.021002524),
#  ('StephenVogt', 0.02083236),
#  ('ChrisStewart', 0.02076337),
#  ('JosePirela', 0.020713717),
#  ('MacWilliamson', 0.020604199),
#  ('VictorReyes', 0.020557454),
#  ('JakeElmore', 0.020424908),
#  ('AlexBregman', 0.0204245),
#  ...]
